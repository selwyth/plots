# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

plt.xkcd()

fig = plt.figure()
data = np.ones(100)
data[70:] -= np.linspace(0,1,30)

plt.annotate(
    'nz beats sa!!',
    xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(115, 1.5))

plt.plot(data, label = 'jing')

david = np.array(np.ones(100))* 0.5 
david[70:] = np.linspace(0.5,2.5,30)

plt.plot(david, label = 'dfeng')

ashley = np.array(np.ones(100)) * 0.25
ashley[40:70] = np.linspace(0.25,1.5,30)
ashley[70:] = np.linspace(1.5,0,30)

plt.plot(ashley, label = 'ashley')

raghav = np.array(np.ones(100)) * 0.1

plt.plot(raghav, label = 'raghav')

plt.xlabel('time')
plt.ylabel('chance of winning world cup pool')
plt.xticks([])
plt.yticks([])
plt.ylim([0,2.5])
plt.legend(loc = 'best')

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np

plt.xkcd()

fig = plt.figure()
data = -np.exp2(np.linspace(0,4,70))

# plt.annotate(
#     'nz beats sa!!',
#     xy=(70, 1), arrowprops=dict(arrowstyle='->'), xytext=(115, 1.5))

plt.plot(data, c = 'black')

plt.xlabel('time since interview')
plt.ylabel('confidence in performance')
plt.xticks([])
plt.yticks([])
plt.ylim([-20,0])
plt.xlim([0,100])

plt.annotate('event horizon', xy=(70,-16), xytext=(30,-16), arrowprops=dict(arrowstyle='->'))

from matplotlib.patches import Rectangle
plt.gca().add_patch(Rectangle((85-15, -16-4), 30, 20, facecolor='lightgrey'))
plt.annotate('black\nhole', xy=(85,-10), xytext=(85,-10), ha='center', va = 'center')

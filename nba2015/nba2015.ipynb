# %%
import matplotlib.pyplot as plt
from matplotlib import ticker
from matplotlib.patches import Rectangle
# %matplotlib inline
import numpy as np

fig, ax = plt.subplots(figsize=(9,15))
plt.xlim(0,8)
ax.set_ylim(0,16)

ax.yaxis.set_minor_locator(ticker.FixedLocator(np.arange(.5,16.5)))
ax.yaxis.set_minor_formatter(ticker.FixedFormatter(range(1,17)))
# ax.yaxis.set_major_formatter(ticker.NullFormatter())
ax.yaxis.set_major_locator(ticker.FixedLocator(range(1,17)))
ax.xaxis.set_major_locator(ticker.NullLocator())
ax.tick_params(axis='y', labelleft=False)
plt.grid(b=True, which='major', axis='y')

ax.add_patch(Rectangle(xy=(0,0), width=1, height=1, facecolor='#FFCC33', edgecolor='#04529C', lw=2))
ax.add_patch(Rectangle(xy=(0,1), width=1, height=1, facecolor='#FFCC33', edgecolor='#04529C', lw=2))

ax.add_patch(Rectangle(xy=(1,2), width=1, height=1, facecolor='#860038', edgecolor='#FD8830', lw=2))
ax.add_patch(Rectangle(xy=(1,4), width=1, height=1, facecolor='#860038', edgecolor='#FD8830', lw=2))

ax.add_patch(Rectangle(xy=(2,5), width=1, height=1, facecolor='#EE2944', edgecolor='#146AA2', lw=2))
ax.add_patch(Rectangle(xy=(2,6), width=1, height=1, facecolor='#EE2944', edgecolor='#146AA2', lw=2))

ax.add_patch(Rectangle(xy=(3,3), width=1, height=1, facecolor='#C0C0C0', edgecolor='#FF0000', lw=2))
ax.add_patch(Rectangle(xy=(3,9), width=1, height=1, facecolor='#C0C0C0', edgecolor='#FF0000', lw=2))

ax.add_patch(Rectangle(xy=(4,7), width=1, height=1, facecolor='#CE1138', edgecolor='#CCCCCC', lw=2))
ax.add_patch(Rectangle(xy=(4,11), width=1, height=1, facecolor='#CE1138', edgecolor='#CCCCCC', lw=2))

ax.add_patch(Rectangle(xy=(5,8), width=1, height=1, facecolor='#D4001F', edgecolor='#000000', lw=2))
ax.add_patch(Rectangle(xy=(5,10), width=1, height=1, facecolor='#D4001F', edgecolor='#000000', lw=2))

ax.add_patch(Rectangle(xy=(6,12), width=1, height=1, facecolor='#002244', edgecolor='#C60C30', lw=2))
ax.add_patch(Rectangle(xy=(6,13), width=1, height=1, facecolor='#002244', edgecolor='#C60C30', lw=2))

ax.add_patch(Rectangle(xy=(7,14), width=1, height=1, facecolor='#7399C6', edgecolor='#001F70', lw=2))
ax.add_patch(Rectangle(xy=(7,15), width=1, height=1, facecolor='#7399C6', edgecolor='#001F70', lw=2))

# plt.plot([1,1], [0,2], color='#FFCC33', linewidth=2.5) # Warriors
# plt.plot([2,2], [2,3], color='#860038', linewidth=2.5) # Cavs
# plt.plot([2,2], [4,5], color='#860038', linewidth=2.5) # Clips
# plt.plot([3,3], [5,7], color='#146AA2', linewidth=2.5) # 
# plt.plot([4,4], [3,10], color='#C0C0C0', linewidth=2.5)
# plt.plot([5,5], [7,12], color='#CE1138', linewidth=2.5)

# %%
teams = {
    'Warriors': [1,2],
    'Cavaliers': [3,5],
    'Clippers': [6,7],
    'Hawks': [4,10],
    'Rockets': [8,12],
    'Bulls': [9,11],
    'Wizards': [13,14],
    'Grizzlies': [15,16]
    }

from pandas import DataFrame
teams2 = DataFrame(teams)

f, ax = plt.subplots(figsize=(12, 12))
sns.heatmap(teams2, linewidths=0, square=True)

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.DataFrame({'date': [pd.datetime(2015,5,1), pd.datetime(2015,5,2), pd.datetime(2015,5,3), 
                            pd.datetime(2015,5,5), pd.datetime(2015,5,6), pd.datetime(2015,5,7)],
                   'A': [8,4,6,None,2,11],
                   'B': [20,None,31,None,31,19],
                   'C': [10,None,None,7,7,29]})

df.index = df.date
df
# Out:
#              A   B   C       date
# date
# 2015-05-01   8  20  10 2015-05-01
# 2015-05-02   4 NaN NaN 2015-05-02
# 2015-05-03   6  31 NaN 2015-05-03
# 2015-05-05 NaN NaN   7 2015-05-05
# 2015-05-06   2  31   7 2015-05-06
# 2015-05-07  11  19  29 2015-05-07

# %%
df.plot(marker='o')
